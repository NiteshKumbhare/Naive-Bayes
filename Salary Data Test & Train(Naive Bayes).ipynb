# %%
from sklearn.naive_bayes import CategoricalNB
clf=CategoricalNB()

# %%
import pandas as pd
NB1=pd.read_csv("Downloads\\SalaryData_Test.csv")
NB1
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
NB2=pd.read_csv("Downloads\\SalaryData_Train.csv")
NB2
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
NB1new = NB1.drop(NB1.columns[[0,3,9,10,11]], axis=1)
NB1new
# Out:
#            workclass      education        maritalstatus          occupation  \
# 0            Private           11th        Never-married   Machine-op-inspct
# 1            Private        HS-grad   Married-civ-spouse     Farming-fishing
# 2          Local-gov     Assoc-acdm   Married-civ-spouse     Protective-serv
# 3            Private   Some-college   Married-civ-spouse   Machine-op-inspct
# 4            Private           10th        Never-married       Other-service
# ...              ...            ...                  ...                 ...
# 15055        Private      Bachelors        Never-married      Prof-specialty
# 15056        Private      Bachelors             Divorced      Prof-specialty
# 15057        Private      Bachelors   Married-civ-spouse      Prof-specialty
# 15058        Private      Bachelors             Divorced        Adm-clerical
# 15059   Self-emp-inc      Bachelors   Married-civ-spouse     Exec-managerial
#
# ...

# %%
NB2new=df = NB2.drop(NB2.columns[[0,3,9,10,11]], axis=1)
NB2new
# Out:
#                workclass    education        maritalstatus  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 30156            Private   Assoc-acdm   Married-civ-spouse
# 30157            Private      HS-grad   Married-civ-spouse
# 30158            Private      HS-grad              Widowed
# 30159            Private      HS-grad        Never-married
# 30160       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex          native  \
# 0            Adm-clerical   Not-in-family   White     Male   United-States
# 1         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
NB1new_label=NB1new.copy()

# %%
NB2new_label=NB2new.copy()

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
NB1new_label.iloc[:,-1]=labelencoder.fit_transform(NB1new_label.iloc[:,-1])
NB1new_label.iloc[:,0]=labelencoder.fit_transform(NB1new_label.iloc[:,0])
NB1new_label.iloc[:,1]=labelencoder.fit_transform(NB1new_label.iloc[:,1])
NB1new_label.iloc[:,2]=labelencoder.fit_transform(NB1new_label.iloc[:,2])
NB1new_label.iloc[:,3]=labelencoder.fit_transform(NB1new_label.iloc[:,3])
NB1new_label.iloc[:,4]=labelencoder.fit_transform(NB1new_label.iloc[:,4])
NB1new_label.iloc[:,5]=labelencoder.fit_transform(NB1new_label.iloc[:,5])
NB1new_label.iloc[:,6]=labelencoder.fit_transform(NB1new_label.iloc[:,6])
NB1new_label.iloc[:,7]=labelencoder.fit_transform(NB1new_label.iloc[:,7])

# %%
NB1new_label
# Out:
#        workclass  education  maritalstatus  occupation  relationship  race  \
# 0              2          1              4           6             3     2
# 1              2         11              2           4             0     4
# 2              1          7              2          10             0     4
# 3              2         15              2           6             0     2
# 4              2          0              4           7             1     4
# ...          ...        ...            ...         ...           ...   ...
# 15055          2          9              4           9             3     4
# 15056          2          9              0           9             1     4
# 15057          2          9              2           9             0     4
# 15058          2          9              0           0             3     1
# 15059          3          9              2           3             0     4
#
#        sex  native  Salary
# 0        1      37       0
# ...

# %%
NB2new_label.iloc[:,-1]=labelencoder.fit_transform(NB2new_label.iloc[:,-1])
NB2new_label.iloc[:,0]=labelencoder.fit_transform(NB2new_label.iloc[:,0])
NB2new_label.iloc[:,1]=labelencoder.fit_transform(NB2new_label.iloc[:,1])
NB2new_label.iloc[:,2]=labelencoder.fit_transform(NB2new_label.iloc[:,2])
NB2new_label.iloc[:,3]=labelencoder.fit_transform(NB2new_label.iloc[:,3])
NB2new_label.iloc[:,4]=labelencoder.fit_transform(NB2new_label.iloc[:,4])
NB2new_label.iloc[:,5]=labelencoder.fit_transform(NB2new_label.iloc[:,5])
NB2new_label.iloc[:,6]=labelencoder.fit_transform(NB2new_label.iloc[:,6])
NB2new_label.iloc[:,7]=labelencoder.fit_transform(NB2new_label.iloc[:,7])

# %%
NB2new_label
# Out:
#        workclass  education  maritalstatus  occupation  relationship  race  \
# 0              5          9              4           0             1     4
# 1              4          9              2           3             0     4
# 2              2         11              0           5             1     4
# 3              2          1              2           5             0     2
# 4              2          9              2           9             5     2
# ...          ...        ...            ...         ...           ...   ...
# 30156          2          7              2          12             5     4
# 30157          2         11              2           6             0     4
# 30158          2         11              6           0             4     4
# 30159          2         11              4           0             3     4
# 30160          3         11              2           3             5     4
#
#        sex  native  Salary
# 0        1      37       0
# ...

# %%
x1=NB1new_label.iloc[:,:-1]
y1=NB1new_label.iloc[:,-1]

# %%
x2=NB2new_label.iloc[:,:-1]
y2=NB2new_label.iloc[:,-1]

# %%
clf.fit(x1,y1)
# Out:
# CategoricalNB()

# %%
clf.fit(x2,y2)
# Out:
# CategoricalNB()

# %%
import numpy as np

# %%
#<=50K:0,>50K:1;
#Private=2,11th=1,Never-married=4,Machine-op-inspct=6,Own-child=3,Black=2,Male=1,United-States=37;
x1_test=np.array([[2,1,4,6,3,2,1,37]])

# %%
print(clf.predict(x1_test))
# Out:
# [0]

# %%
clf.predict_proba(x1_test)
# Out:
# array([[9.99903937e-01, 9.60627381e-05]])

# %%
#Local-gov=1,Assoc-acdm=7,Married-civ-spouse=2,Protective-serv=10,Husband=0,White=4,Male=1,United-States=37;
x1_test=np.array([[1,7,2,10,0,4,1,37]])

# %%
print(clf.predict(x1_test))
# Out:
# [1]

# %%
clf.predict_proba(x1_test)
# Out:
# array([[0.14083036, 0.85916964]])

# %%
#State-gov=5,Bachelors=9,Never-married=4,Adm-clerical=0,Not-in-family=1,White=4,Male=1,United-States=37;
x2_test=np.array([[5,9,4,0,1,4,1,37]])

# %%
print(clf.predict(x2_test))
# Out:
# [0]

# %%
clf.predict_proba(x2_test)
# Out:
# array([[0.96913859, 0.03086141]])

# %%
#Self-emp-inc=3,HS-grad=11,Married-civ-spouse=2,Exec-managerial=3,Wife=5,White=4,Female=0,United-States=37;
x2_test=np.array([[3,11,2,3,5,4,0,37]])

# %%
print(clf.predict(x2_test))
# Out:
# [1]

# %%
clf.predict_proba(x2_test)
# Out:
# array([[0.12889287, 0.87110713]])
